# %%
import cv2
import numpy as np

# Read image.
img = cv2.imread('gps-lte__eksacwutyu2q_og.png', cv2.IMREAD_COLOR)

# Convert to grayscale.
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Blur using 3 * 3 kernel.
gray_blurred = cv2.blur(gray, (3, 3))

# Apply Hough transform on the blurred image.
detected_circles = cv2.HoughCircles(gray_blurred,
				cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
			param2 = 30, minRadius = 1, maxRadius = 40)

# Draw circles that are detected.
if detected_circles is not None:

	# Convert the circle parameters a, b and r to integers.
	detected_circles = np.uint16(np.around(detected_circles))

	for pt in detected_circles[0, :]:
		a, b, r = pt[0], pt[1], pt[2]

		# Draw the circumference of the circle.
		cv2.circle(img, (a, b), r, (0, 255, 0), 2)

		# Draw a small circle (of radius 1) to show the center.
		cv2.circle(img, (a, b), 1, (0, 0, 255), 3)
		cv2.imshow("Detected Circle", img)
		cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [9], line 8
#       5 img = cv2.imread('gps-lte__eksacwutyu2q_og.png', cv2.IMREAD_COLOR)
#       7 # Convert to grayscale.
# ----> 8 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      10 # Blur using 3 * 3 kernel.
#      11 gray_blurred = cv2.blur(gray, (3, 3))
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
import cv2
import numpy as np
class image_processing():
    def __init__(self,path,kernel=(5,5)):
        self.kernel = np.ones((kernel[0],kernel[1]),np.uint8)
        self.image = cv2.imread(path,0)
        cv2.imshow("original",self.image)
        cv2.waitKey(0)
    def erosion(self):
        self.ero = cv2.erode(self.image,self.kernel,iterations=1)
        cv2.imshow("erosion",self.ero)
        return self.ero

proc = image_processing("practicum\operations_1.jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [15], line 15
#      12         cv2.imshow("erosion",self.ero)
#      13         return self.ero
# ---> 15 proc = image_processing("practicum\operations_1.jpg")
#
# Cell In [15], line 8, in image_processing.__init__(self, path, kernel)
#       6 self.kernel = np.ones((kernel[0],kernel[1]),np.uint8)
#       7 self.image = cv2.imread(path,0)
# ----> 8 cv2.imshow("original",self.image)
#       9 cv2.waitKey(0)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import cv2
import numpy as np
 
# Reading the input image
img = cv2.imread("practicum\operations_1.jpg", 0)
cv2.imshow("original",img)
# Taking a matrix of size 5 as the kernel
kernel = np.ones((5, 5), np.uint8)
img_erosion = cv2.erode(img, kernel, iterations=1)
img_dilation = cv2.dilate(img, kernel, iterations=1)
 
cv2.imshow('Input', img)
cv2.imshow('Erosion', img_erosion)
cv2.imshow('Dilation', img_dilation)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [1], line 6
#       4 # Reading the input image
#       5 img = cv2.imread("practicum\operations_1.jpg", 0)
# ----> 6 cv2.imshow("original",img)
#       7 # Taking a matrix of size 5 as the kernel
#       8 kernel = np.ones((5, 5), np.uint8)
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:967: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("shanghai.jpeg",cv.IMREAD_GRAYSCALE)
equ = cv.equalizeHist(img)
res = np.hstack((img,equ))
cv.imshow("img",img)
plt.hist(img.ravel(),256,[0,256])
cv.waitKey(0)
cv.destroyAllWindows()
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("shanghai.jpeg")
cv.imshow("img",img)
plt.hist(img.ravel(),256,[0,256])
cv.waitKey(0)
cv.destroyAllWindows()
plt.show()

# %%
import cv2
from skimage import io
from matplotlib import pyplot as plt
img = cv2.imread("shanghai.jpeg",cv2.COLOR_BGR2LAB)
l,a,b = cv2.split(img)
plt.hist(l.flat,bins=100,range=(0,255))
plt.show()
plt.imshow(l,cmap="gray")

# %%
equ = cv2.equalizeHist(l)
plt.hist(equ.flat,bins=100,range=(0,255))
plt.show()
plt.imshow(equ,cmap='gray')
